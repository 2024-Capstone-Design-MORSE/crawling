# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import pandas as pd
import time

# 레시피명과 URL 정보를 저장할 리스트 초기화
recipe_name_list = []
url_list = []
view_list = []
img_list = []
recipe_img_list = []

# 브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

# 불필요한 에러 메세지 없애기
chrome_options.add_experimental_option("excludeSwitches", ["enable-logging"])

# ChromeDriverManager 자동설치
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

try:
    # 페이지를 순회하면서 데이터 수집
    for page_num in range(1, 10):  # 1부터 101페이지까지
        
        url = f'https://www.10000recipe.com/recipe/list.html?order=reco&page={page_num}'
        driver.get(url)
        time.sleep(1)
        
        WebDriverWait(driver, 10)  # 웹 페이지가 로드될 때까지, 최대 10초간 기다린다는 뜻

        # Selenium으로 javascript 실행된 후의 페이지 소스를 가져옴
        html = driver.page_source
        
        # Beautifulsoup 으로 파싱
        soup = BeautifulSoup(html, 'html.parser')
        
        # box_contents 찾기
        box_contents = soup.find_all('li', class_='common_sp_list_li')
        
        # 이하 데이터 처리 로직...
        print(f"Page {page_num}: Found {len(box_contents)} box_contents")
        
        for box_content in box_contents:
            # 조회수 데이터 추출
            view_data = box_content.find('span', class_='common_sp_caption_buyer').text.split()[1]
            
            # '만'을 포함하거나, '만'이 없으면서 조회수가 5,000 이상인 경우
            if '만' in view_data:
                should_add = True
                view_list.append(view_data)
            else:
                # 쉼표 제거 후 숫자형으로 변환 가능한지 확인하고, 5,000 이상인 경우 리스트에 추가
                view_count = view_data.replace(',', '')
                if view_count.isdigit() and int(view_count) >= 5000:
                    should_add = True
                    view_list.append(view_data)
                else:
                    should_add = False
                    
            # 조회수 조건을 충족하는 경우에만 img_link 정보를 리스트에 추가
            # 레시피 이미지 링크 수집을 위한 이미지 리스트 초기화
            img_list = [] 
        
            if should_add:
                img_tags = box_content.find_all('a', class_='common_sp_link')
                for img_tag in img_tags:
                    img_links = img_tag.select('img')  
                    for img_link in img_links: 
                        img_list.append(img_link['src'])
                        
            # 레시피 이미지를 포함하는 링크 정보를 recipe_img_list에 추가
            # 처음에는 문자열 'm.jpg'를 포함하는 링크 정보를 추가하였으나 결과값이 39개 나와 문자열'cache'로 수정                     
                for recipe_link in img_list:
                    if 'cache' in recipe_link:
                        recipe_img_list.append(recipe_link) 
                    
            # 조회수 조건을 충족하는 경우에만 레시피명과 URL 정보를 리스트에 추가
            if should_add:
                recipe_name = box_content.find('div', class_='common_sp_caption_tit line2').text.strip()
                url = "https://www.10000recipe.com" + box_content.find('a')['href']
                recipe_name_list.append(recipe_name)
                url_list.append(url)
                
            # 각 리스트별 개수가 같은지 확인
            print(f"레시피 이름 {len(recipe_name_list)}개 / url주소 {len(url_list)}개 / 조회수 {len(view_list)}개 / 레시피 이미지 {len(recipe_img_list)}개")
                
        # 각 리스트별 리스트 개수가 쌓이는 개수를 확인
        print(f"레시피 이름 {len(recipe_name_list)}개 / url주소 {len(url_list)}개 / 조회수 {len(view_list)}개 / 레시피 이미지 {len(recipe_img_list)}개")
    # 최종개수를 확인
    print(f" 최종개수 : 레시피 이름 {len(recipe_name_list)}개 / url주소 {len(url_list)}개 / 조회수 {len(view_list)}개 / 레시피 이미지 {len(recipe_img_list)}개")
            
finally:
    # 드라이버 종료는 모든 작업이 끝난 후에 한 번만 수행
    driver.quit()
 
# 최종개수를 확인
print(f" 최종개수 : 레시피 이름 {len(recipe_name_list)}개 / url주소 {len(url_list)}개 / 조회수 {len(view_list)}개 / 레시피 이미지 {len(recipe_img_list)}개")      

# 데이터 저장
data = {'name':recipe_name_list, 'link':url_list, 'viewNumber': view_list, 'imageURL':recipe_img_list}
df = pd.DataFrame(data)
        
df.to_csv('만개의레시피(3290개).csv', index=False, encoding='utf-8-sig')
# Out:
# Page 1: Found 40 box_contents
# 레시피 이름 1개 / url주소 1개 / 조회수 1개 / 레시피 이미지 1개
# 레시피 이름 1개 / url주소 1개 / 조회수 1개 / 레시피 이미지 1개
# 레시피 이름 1개 / url주소 1개 / 조회수 1개 / 레시피 이미지 1개
# 레시피 이름 2개 / url주소 2개 / 조회수 2개 / 레시피 이미지 2개
# 레시피 이름 3개 / url주소 3개 / 조회수 3개 / 레시피 이미지 3개
# 레시피 이름 3개 / url주소 3개 / 조회수 3개 / 레시피 이미지 3개
# 레시피 이름 4개 / url주소 4개 / 조회수 4개 / 레시피 이미지 4개
# 레시피 이름 5개 / url주소 5개 / 조회수 5개 / 레시피 이미지 5개
# 레시피 이름 5개 / url주소 5개 / 조회수 5개 / 레시피 이미지 5개
# 레시피 이름 6개 / url주소 6개 / 조회수 6개 / 레시피 이미지 6개
# 레시피 이름 7개 / url주소 7개 / 조회수 7개 / 레시피 이미지 7개
# 레시피 이름 8개 / url주소 8개 / 조회수 8개 / 레시피 이미지 8개
# 레시피 이름 8개 / url주소 8개 / 조회수 8개 / 레시피 이미지 8개
# 레시피 이름 8개 / url주소 8개 / 조회수 8개 / 레시피 이미지 8개
# 레시피 이름 8개 / url주소 8개 / 조회수 8개 / 레시피 이미지 8개
# 레시피 이름 9개 / url주소 9개 / 조회수 9개 / 레시피 이미지 9개
# 레시피 이름 9개 / url주소 9개 / 조회수 9개 / 레시피 이미지 9개
# 레시피 이름 10개 / url주소 10개 / 조회수 10개 / 레시피 이미지 10개
# 레시피 이름 11개 / url주소 11개 / 조회수 11개 / 레시피 이미지 11개
# 레시피 이름 11개 / url주소 11개 / 조회수 11개 / 레시피 이미지 11개
# 레시피 이름 11개 / url주소 11개 / 조회수 11개 / 레시피 이미지 11개
# 레시피 이름 11개 / url주소 11개 / 조회수 11개 / 레시피 이미지 11개
# 레시피 이름 11개 / url주소 11개 / 조회수 11개 / 레시피 이미지 11개
# 레시피 이름 11개 / url주소 11개 / 조회수 11개 / 레시피 이미지 11개
# 레시피 이름 12개 / url주소 12개 / 조회수 12개 / 레시피 이미지 12개
# 레시피 이름 12개 / url주소 12개 / 조회수 12개 / 레시피 이미지 12개
# 레시피 이름 12개 / url주소 12개 / 조회수 12개 / 레시피 이미지 12개
# 레시피 이름 13개 / url주소 13개 / 조회수 13개 / 레시피 이미지 13개
# 레시피 이름 13개 / url주소 13개 / 조회수 13개 / 레시피 이미지 13개
# 레시피 이름 13개 / url주소 13개 / 조회수 13개 / 레시피 이미지 13개
# 레시피 이름 13개 / url주소 13개 / 조회수 13개 / 레시피 이미지 13개
# 레시피 이름 14개 / url주소 14개 / 조회수 14개 / 레시피 이미지 14개
# 레시피 이름 15개 / url주소 15개 / 조회수 15개 / 레시피 이미지 15개
# 레시피 이름 16개 / url주소 16개 / 조회수 16개 / 레시피 이미지 16개
# 레시피 이름 17개 / url주소 17개 / 조회수 17개 / 레시피 이미지 17개
# 레시피 이름 72개 / url주소 72개 / 조회수 72개 / 레시피 이미지 72개
# 레시피 이름 72개 / url주소 72개 / 조회수 72개 / 레시피 이미지 72개
# 레시피 이름 73개 / url주소 73개 / 조회수 73개 / 레시피 이미지 73개
# 레시피 이름 74개 / url주소 74개 / 조회수 74개 / 레시피 이미지 74개
# 레시피 이름 75개 / url주소 75개 / 조회수 75개 / 레시피 이미지 75개
# 레시피 이름 75개 / url주소 75개 / 조회수 75개 / 레시피 이미지 75개
# 레시피 이름 75개 / url주소 75개 / 조회수 75개 / 레시피 이미지 75개
# 레시피 이름 76개 / url주소 76개 / 조회수 76개 / 레시피 이미지 76개
# 레시피 이름 77개 / url주소 77개 / 조회수 77개 / 레시피 이미지 77개
# 레시피 이름 78개 / url주소 78개 / 조회수 78개 / 레시피 이미지 78개
# 레시피 이름 78개 / url주소 78개 / 조회수 78개 / 레시피 이미지 78개
# 레시피 이름 79개 / url주소 79개 / 조회수 79개 / 레시피 이미지 79개
# 레시피 이름 79개 / url주소 79개 / 조회수 79개 / 레시피 이미지 79개
# 레시피 이름 80개 / url주소 80개 / 조회수 80개 / 레시피 이미지 80개
# 레시피 이름 80개 / url주소 80개 / 조회수 80개 / 레시피 이미지 80개
# Page 4: Found 40 box_contents
# 레시피 이름 81개 / url주소 81개 / 조회수 81개 / 레시피 이미지 81개
# 레시피 이름 82개 / url주소 82개 / 조회수 82개 / 레시피 이미지 82개
# 레시피 이름 83개 / url주소 83개 / 조회수 83개 / 레시피 이미지 83개
# 레시피 이름 84개 / url주소 84개 / 조회수 84개 / 레시피 이미지 84개
# 레시피 이름 85개 / url주소 85개 / 조회수 85개 / 레시피 이미지 85개
# 레시피 이름 86개 / url주소 86개 / 조회수 86개 / 레시피 이미지 86개
# 레시피 이름 87개 / url주소 87개 / 조회수 87개 / 레시피 이미지 87개
# 레시피 이름 88개 / url주소 88개 / 조회수 88개 / 레시피 이미지 88개
# 레시피 이름 89개 / url주소 89개 / 조회수 89개 / 레시피 이미지 89개
# 레시피 이름 90개 / url주소 90개 / 조회수 90개 / 레시피 이미지 90개
# 레시피 이름 91개 / url주소 91개 / 조회수 91개 / 레시피 이미지 91개
# 레시피 이름 92개 / url주소 92개 / 조회수 92개 / 레시피 이미지 92개
# 레시피 이름 93개 / url주소 93개 / 조회수 93개 / 레시피 이미지 93개
# 레시피 이름 94개 / url주소 94개 / 조회수 94개 / 레시피 이미지 94개
# 레시피 이름 95개 / url주소 95개 / 조회수 95개 / 레시피 이미지 95개
# 레시피 이름 96개 / url주소 96개 / 조회수 96개 / 레시피 이미지 96개
# 레시피 이름 97개 / url주소 97개 / 조회수 97개 / 레시피 이미지 97개
# 레시피 이름 98개 / url주소 98개 / 조회수 98개 / 레시피 이미지 98개
# 레시피 이름 99개 / url주소 99개 / 조회수 99개 / 레시피 이미지 99개
# 레시피 이름 99개 / url주소 99개 / 조회수 99개 / 레시피 이미지 99개
# 레시피 이름 100개 / url주소 100개 / 조회수 100개 / 레시피 이미지 100개
# 레시피 이름 286개 / url주소 286개 / 조회수 286개 / 레시피 이미지 286개
# 레시피 이름 287개 / url주소 287개 / 조회수 287개 / 레시피 이미지 287개
# 레시피 이름 288개 / url주소 288개 / 조회수 288개 / 레시피 이미지 288개
# 레시피 이름 289개 / url주소 289개 / 조회수 289개 / 레시피 이미지 289개
# 레시피 이름 290개 / url주소 290개 / 조회수 290개 / 레시피 이미지 290개
# 레시피 이름 290개 / url주소 290개 / 조회수 290개 / 레시피 이미지 290개
#  최종개수 : 레시피 이름 290개 / url주소 290개 / 조회수 290개 / 레시피 이미지 290개
#  최종개수 : 레시피 이름 290개 / url주소 290개 / 조회수 290개 / 레시피 이미지 290개

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException, TimeoutException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import UnexpectedAlertPresentException
from bs4 import BeautifulSoup
import pandas as pd
import time

# 브라우저 꺼짐 방지
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

# 불필요한 에러 메세지 없애기
chrome_options.add_experimental_option("excludeSwitches", ["enable-logging"])

# ChromeDriverManager 자동설치
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

try:
    # 모든 레시피 재료 정보를 저장할  리스트
    all_recipes_ingredients = []
    all_recipes_ingredients_num = []
    review_list = []
    
    # 제거할 인덱스를 저장할 리스트
    indexes_to_remove = []
    
    recipe_number = 0
    # url_list를 돌면서 페이지마다 재료정보 가져오기
    for index, url in enumerate(url_list):
        try:
            driver.get(url)
            WebDriverWait(driver, 10)  # 웹 페이지가 로드될 때까지, 최대 10초간 기다린다는 뜻
            time.sleep(1)

            # Selenium으로 javascript 실행된 후의 페이지 소스를 가져옴
            html = driver.page_source

            # Beautifulsoup 으로 파싱
            soup = BeautifulSoup(html, 'html.parser')

            # 현재 레시피의 모든 재료를 저장할 리스트
            current_recipe_ingredients = []

            # 재료 정보에 해당하는 태그정보를 가져오기
            div_tags = soup.select_one('div.ready_ingre3') # class가 'ready_ingre3'인 div 태그 선택
            ul_tag = div_tags.select_one('ul')
            div_tags = ul_tag.find_all('div', class_='ingre_list_name')

            sauce_list = ['진간장', '통깨', '굴소스', '소금', '올리고당', '설탕', '맛간장', '맛소금' 
                          '참기름', '식용유', '후추가루', '간장', '깨소금', '식초', '후춧가루', '매실액','참치액젓','간장'
                          '멸치액젓', '들깨가루', '볶음참깨', '미림','들기름', '깨', '후추', '참치액', '흑설탕', '황설탕',''
                          '국간장', '육수', '물', '멸치육수', '올리브오일', '전분가루', '마요네즈', '매실청', '양조간장', '현미유',
                          '감자전분', '고추가루', '기름', '파슬리가루', '생수', '고춧가루', '케챱', '캐찹', '캐첩', '케첩', '캐챱',
                          '부침가루', '다진 홍고추', '다진 부추', '다진 양파', '참깨','굴소스', '올리고당', '고추장', '간장', '물', 
                          '다진마늘', '식초', '설탕', '깨', '들기름', '후춧가루',
                          '매실액', '참기름','통깨','진간장','고춧가루','후추' , '마요네즈', '머스타드소스',
                          '소금', '파슬리가루', '파슬리', '오일', '굴소스', '식용유', '밥', '맛소금',
                          '파마산치즈가루', '다이제스티브', '녹인버터', '맛술', '레몬즙', '발사믹', '바질', '된장',
                          '슬라이스아몬드' , '참치액젓', '국간장' , '다진 쪽파', '자른 다시마', '케찹',
                          '생강가루', '굵은소금', '갈은 마늘', '천일염','다진파', '머스터드',
                          '간 마늘', '검은깨', '꿀', '대파 흰부분', '파마산 치즈','깨소금', '다진청양고추', '백설탕', '통후추',
                          '물엿', '케첩', '케챱', '대파(줄기)', '다진생강 (즙)', '올리고 당', '레드페퍼', '땡초'
                          '쪽파 썰어준 것', '생크림', '미림','건바질','시나몬', '시나몬 가루', '시나몬가루',
                          '스테이크 소스', '스테이크소스', '견과류', '꽃소금', '연두', '생강술(미림맛술)', '청주', '케찹',
                          '스위트 칠리소스', '스위트칠리소스','올리브유', '카놀라유', '필링용 딸기잼', '황설탕', '흑설탕',
                          '다진홍청양고추', '다진양파', '청양고추 매콤하게 먹고싶으면', '스톡 이나 굴소스',  '다진마늘 보다적게', 
                          '참기름 보다적게', '냉장고속채소', '일반 후라이팬', '허브소금', '다진 마늘', '다진 생강', 
                          '허니머스타드', '장식용 설탕', '굵은 소금', '카놀라유 올리브유 빼고', '햇반 1개', '햇반',
                          '소주 또는 맛술', '햇반 1개', '대파 손가락 길이', '견과류 아몬드or땅콩 생략 가능',
                          '맛간장 OR진간장', '각종자투리 야채', '설탕 적은', '스리라차소스', '스리라차', '스리라차 소스',
                          '쥐똥고추 or청양고추'
                          
                         ]

            for ingre_tag in div_tags:
                a_tag = ingre_tag.find('a')
                if a_tag:  # 만약 <a> 태그가 존재하면
                    ingredient = ' '.join(a_tag.text.strip().split())  # 문자열 내의 모든 공백을 제거하고, 불필요한 공백을 최소화
                    if ingredient not in sauce_list:  # 재료가 소스 리스트에 포함되어 있지 않다면
                        current_recipe_ingredients.append(ingredient)
                    else:
                        continue  # 재료가 소스 리스트에 포함되어 있다면, 이 재료는 무시하고 넘어감. 
            recipe_number += 1 

            all_recipes_ingredients_num.append(len(current_recipe_ingredients))
            # 양념을 제외한 재료 개수, 재료정보를 확인하기 위한 용도
            print(f"재료의 개수:{len(current_recipe_ingredients)} 재료 리스트:{current_recipe_ingredients} {recipe_number}번째 레시피")
            all_recipes_ingredients.append(current_recipe_ingredients)

            # 현재 레시피의 리뷰 수 가져오기
            review_spans = WebDriverWait(driver, 10).until(
                EC.presence_of_all_elements_located((By.CSS_SELECTOR, '.reply_tit span'))
            )

            review_count = 0
            for span in review_spans:
                r_text = span.text.strip()  # 텍스트 앞뒤 공백 제거
                if r_text.isdigit():  # 텍스트가 숫자인지 확인
                    review_count += int(r_text)  # 숫자라면 정수로 변환하여 누적
            
            review_list.append(review_count)
        
        except TimeoutException:
            print("제한 시간 초과")
            # 제한 시간이 초과되면 해당 URL을 url_list에서 제거
            indexes_to_remove.append(index)
        except NoSuchElementException:
            print("요소를 찾을 수 없음")
            indexes_to_remove.append(index)
        except UnexpectedAlertPresentException:
            print("알 수 없는 경고가 발생")
            # 알 수 없는 경고가 발생할 경우 해당 URL을 url_list에서 제거
            indexes_to_remove.append(index)
            continue

except Exception as e:
    print("예상치 못한 오류 발생:", e)
    

finally:
    # 드라이버 종료는 모든 작업이 끝난 후에 한 번만 수행
    driver.quit()
    
# url_list에서 해당하는 인덱스를 제거
for index in sorted(indexes_to_remove, reverse=True):
    del url_list[index]
    
# img_list에서 해당하는 인덱스를 제거
for index in sorted(indexes_to_remove, reverse=True):
    del recipe_mg_list[index]

# views_list에서 해당하는 인덱스를 제거
for index in sorted(indexes_to_remove, reverse=True):
    del view_list[index]

# recipe_name_list에서 해당하는 인덱스를 제거
for index in sorted(indexes_to_remove, reverse=True):
    del recipe_name_list[index]
    
# 데이터 저장
data = {'ingredients': all_recipes_ingredients, 'ingreNumber': all_recipes_ingredients_num, 'reviewNumber': review_list} 
df1 = pd.DataFrame(data)

# df1(재료정보 데이터프레임)을 df(레시피명 및 주소정보 데이터프레임)의 왼쪽에 이어 붙임.
result = pd.concat([df, df1], axis=1)
        
# result.to_csv('C:\\Users\\gudrb\\OneDrive\\Desktop\\캡디\\만개의레시피(최종결과)_f.csv', index=False, encoding='utf-8-sig')
# Out:
# 재료의 개수:2 재료 리스트:['감자', '스팸'] 1번째 레시피
# 재료의 개수:2 재료 리스트:['느타리버섯', '애호박'] 2번째 레시피
# 재료의 개수:1 재료 리스트:['콩나물'] 3번째 레시피
# 재료의 개수:4 재료 리스트:['감자', '베이컨', '대파', '양파'] 4번째 레시피
# 재료의 개수:2 재료 리스트:['미니새송이버섯', '버터'] 5번째 레시피
# 재료의 개수:1 재료 리스트:['오이고추'] 6번째 레시피
# 재료의 개수:2 재료 리스트:['새송이버섯', '대파'] 7번째 레시피
# 재료의 개수:2 재료 리스트:['청경채', '쪽파'] 8번째 레시피
# 재료의 개수:3 재료 리스트:['도토리묵', '조미김', '다진대파'] 9번째 레시피
# 재료의 개수:2 재료 리스트:['양파', '비엔나소세지'] 10번째 레시피
# 재료의 개수:3 재료 리스트:['콩나물', '크래미', '대파'] 11번째 레시피
# 재료의 개수:1 재료 리스트:['알배추'] 12번째 레시피
# 재료의 개수:1 재료 리스트:['가시오이'] 13번째 레시피
# 재료의 개수:2 재료 리스트:['고구마', '모짜렐라치즈'] 14번째 레시피
# 재료의 개수:3 재료 리스트:['참치', '양파', '청양고추'] 15번째 레시피
# 재료의 개수:2 재료 리스트:['잔파', '양파'] 16번째 레시피
# 재료의 개수:3 재료 리스트:['두부', '팽이버섯', '대파'] 17번째 레시피
# 재료의 개수:2 재료 리스트:['오징어채', '소주 또는 맛술'] 18번째 레시피
# 재료의 개수:3 재료 리스트:['계란', '양배추', '모짜렐라치즈'] 19번째 레시피
# 재료의 개수:3 재료 리스트:['새송이버섯', '버터', '어린잎채소'] 20번째 레시피
# 재료의 개수:2 재료 리스트:['순두부', '마늘'] 21번째 레시피
# 재료의 개수:2 재료 리스트:['베이컨', '양파'] 22번째 레시피
# 재료의 개수:2 재료 리스트:['햇반 1개', '참치'] 23번째 레시피
# 재료의 개수:4 재료 리스트:['알배추', '두부', '참치', '계란'] 24번째 레시피
# 재료의 개수:4 재료 리스트:['팽이버섯', '대파', '양파', '달걀'] 25번째 레시피
# 재료의 개수:3 재료 리스트:['팽이버섯', '쪽파', '청양고추'] 26번째 레시피
# 재료의 개수:1 재료 리스트:['풋고추'] 27번째 레시피
# 재료의 개수:2 재료 리스트:['건새우', '마늘쫑'] 28번째 레시피
# 재료의 개수:3 재료 리스트:['베이컨', '대파', '떡'] 29번째 레시피
# 재료의 개수:2 재료 리스트:['비엔나 소세지', '양파'] 30번째 레시피
# 재료의 개수:3 재료 리스트:['브로콜리', '두부', '멸치액젓'] 31번째 레시피
# 재료의 개수:4 재료 리스트:['달걀', '양파', '청양고추', '쪽파 또는 대파'] 32번째 레시피
# 재료의 개수:3 재료 리스트:['파프리카', '달걀', '양파'] 33번째 레시피
# 재료의 개수:5 재료 리스트:['감자', '돼지고기 앞다리살', '양파', '청양고추', '대파'] 34번째 레시피
# 재료의 개수:2 재료 리스트:['양파', '슬라이스 마늘'] 35번째 레시피
# 재료의 개수:1 재료 리스트:['오이고추'] 36번째 레시피
# 재료의 개수:3 재료 리스트:['순두부', '대파', '홍고추'] 37번째 레시피
# 재료의 개수:3 재료 리스트:['숙주', '크래미', '오이'] 38번째 레시피
# 재료의 개수:2 재료 리스트:['단무지', '대파 손가락 길이'] 39번째 레시피
# 재료의 개수:3 재료 리스트:['베이컨', '양파', '미니새송이버섯'] 40번째 레시피
# 재료의 개수:6 재료 리스트:['두부', '토마토소스', '양파', '방울토마토', '닭가슴살', '모짜렐라 치즈'] 41번째 레시피
# 재료의 개수:5 재료 리스트:['순두부', '표고버섯', '양파', '대파', '청양고추'] 42번째 레시피
# 재료의 개수:4 재료 리스트:['스팸(小)', '양파', '계란', '대파'] 43번째 레시피
# 재료의 개수:3 재료 리스트:['꽈리고추', '햄', '양파'] 44번째 레시피
# 재료의 개수:2 재료 리스트:['만두 교자만두/물만두', '비엔나소세지 작은거'] 45번째 레시피
# 재료의 개수:2 재료 리스트:['닭봉 500그램', '파프리카'] 46번째 레시피
# 재료의 개수:1 재료 리스트:['배추'] 47번째 레시피
# 재료의 개수:5 재료 리스트:['또띠아', '참치캔', '치즈', '양파', '청양고추'] 48번째 레시피
# 재료의 개수:0 재료 리스트:[] 49번째 레시피
# 재료의 개수:1 재료 리스트:['진미채 크게'] 50번째 레시피
# 재료의 개수:5 재료 리스트:['새송이버섯', '국거리소고기', '양파', '대파', '청양고추'] 51번째 레시피
# 재료의 개수:2 재료 리스트:['비엔나소세지', '떡볶이떡'] 52번째 레시피
# 재료의 개수:6 재료 리스트:['대패삼겹살', '콩나물', '양파', '새송이버섯', '대파', '청양고추'] 53번째 레시피
# 재료의 개수:2 재료 리스트:['오이', '쪽파'] 54번째 레시피
# 재료의 개수:2 재료 리스트:['깻잎', '대파'] 55번째 레시피
# 재료의 개수:1 재료 리스트:['새우'] 56번째 레시피
# 재료의 개수:3 재료 리스트:['느타리버섯', '양파', '대파'] 57번째 레시피
# 재료의 개수:2 재료 리스트:['프랑크소시지', '마늘쫑'] 58번째 레시피
# 재료의 개수:5 재료 리스트:['불린 당면 150g 정도', '새우', '양파', '대파', '고추기름'] 59번째 레시피
# 재료의 개수:4 재료 리스트:['차돌박이', '깻잎', '팽이버섯', '숙주나물'] 60번째 레시피
# 재료의 개수:2 재료 리스트:['부추', '달걀'] 61번째 레시피
# 재료의 개수:5 재료 리스트:['양배추', '양파', '대파', '스팸', '땡초'] 62번째 레시피
# 재료의 개수:2 재료 리스트:['칵테일 새우', '버터'] 63번째 레시피
# 재료의 개수:3 재료 리스트:['칵테일 새우', '부추', '청양고추'] 64번째 레시피
# 재료의 개수:2 재료 리스트:['치킨너겟', '견과류 아몬드or땅콩 생략 가능'] 65번째 레시피
# 재료의 개수:6 재료 리스트:['계란', '당면', '당근', '양파', '쪽파', '청양고추'] 66번째 레시피
# 재료의 개수:3 재료 리스트:['닭고기', '양배추채', '파프리카'] 67번째 레시피
# 재료의 개수:1 재료 리스트:['양배추'] 68번째 레시피
# 재료의 개수:2 재료 리스트:['시금치', '달걀'] 69번째 레시피
# 재료의 개수:4 재료 리스트:['양배추', '참치캔', '계란', '양파'] 70번째 레시피
# 재료의 개수:2 재료 리스트:['오이', '완숙토마토'] 71번째 레시피
# 재료의 개수:4 재료 리스트:['참치캔', '양파', '대파', '청양고추'] 72번째 레시피
# 재료의 개수:1 재료 리스트:['연두부'] 73번째 레시피
# 재료의 개수:4 재료 리스트:['양배추', '후랑크 소시지', '대파', '달걀'] 74번째 레시피
# 재료의 개수:5 재료 리스트:['느타리버섯', '양파', '애호박', '고추', '대파'] 75번째 레시피
# 재료의 개수:4 재료 리스트:['감자', '베이컨', '모짜렐라 치즈', '우유'] 76번째 레시피
# 재료의 개수:3 재료 리스트:['감자 중간사이즈', '스팸', '양파'] 77번째 레시피
# 재료의 개수:4 재료 리스트:['새송이버섯', '청양고추', '대파', '버터'] 78번째 레시피
# 재료의 개수:5 재료 리스트:['참치캔', '양배추', '양파', '대파', '쌀밥'] 79번째 레시피
# 재료의 개수:3 재료 리스트:['시금치', '양파', '계란'] 80번째 레시피
# 재료의 개수:3 재료 리스트:['대패 삼겹살', '대파', '맛간장 OR진간장'] 81번째 레시피
# 재료의 개수:4 재료 리스트:['닭가슴살', '달걀', '양파', '각종자투리 야채'] 82번째 레시피
# 재료의 개수:5 재료 리스트:['콩나물', '비엔나소시지', '대파', '양파', '믈'] 83번째 레시피
# 재료의 개수:1 재료 리스트:['부침용 두부'] 84번째 레시피
# 재료의 개수:6 재료 리스트:['숙주', '새우', '계란', '양파', '대파', '볶은참깨'] 85번째 레시피
# 재료의 개수:3 재료 리스트:['베이컨', '양파', '계란 노른자'] 86번째 레시피
# 재료의 개수:3 재료 리스트:['메추리알', '스팸', '청양고추'] 87번째 레시피
# 재료의 개수:4 재료 리스트:['계란', '양배추', '감자', '슬라이스치즈'] 88번째 레시피
# 재료의 개수:5 재료 리스트:['초콜렛 다크 추천', '카놀라유 올리브유 빼고', '계란', '밀가루 아무거나', '핫초코가루'] 89번째 레시피
# 재료의 개수:2 재료 리스트:['무', '대파'] 90번째 레시피
# 재료의 개수:4 재료 리스트:['황태포', '무', '계란', '파'] 91번째 레시피
# 재료의 개수:1 재료 리스트:['닭다리살'] 92번째 레시피
# 재료의 개수:6 재료 리스트:['달걀', '우유', '마늘', '양파', '버터', '카레가루'] 93번째 레시피
# 재료의 개수:0 재료 리스트:[] 94번째 레시피
# 재료의 개수:5 재료 리스트:['연두부', '새우', '달걀', '송송 썬 쪽파', '다시마 5cm x 5cm'] 95번째 레시피
# 재료의 개수:2 재료 리스트:['팽이버섯', '베이컨'] 96번째 레시피
# 재료의 개수:4 재료 리스트:['팽이버섯', '베이컨', '대파', '버터'] 97번째 레시피
# 재료의 개수:1 재료 리스트:['상추'] 98번째 레시피
# 재료의 개수:2 재료 리스트:['떡볶이떡', '베이컨'] 99번째 레시피
# 재료의 개수:4 재료 리스트:['모닝빵', '옥수수 콘', '허니 머스터드', '피자치즈'] 100번째 레시피
# 재료의 개수:2 재료 리스트:['마늘', '호두'] 101번째 레시피
# 재료의 개수:1 재료 리스트:['깻잎'] 102번째 레시피
# 재료의 개수:2 재료 리스트:['새우', '버터'] 103번째 레시피
# 재료의 개수:4 재료 리스트:['돈까스', '김치', '김치국물', '달걀'] 104번째 레시피
# 재료의 개수:1 재료 리스트:['얼갈이'] 105번째 레시피
# 재료의 개수:6 재료 리스트:['청경채', '부추', '새우', '버섯', '양파', '청양고추'] 106번째 레시피
# 재료의 개수:5 재료 리스트:['생 닭가슴살', '양파', '파프리카 빨강', '파프리카 노랑', '파프리카 초록'] 107번째 레시피
# 재료의 개수:2 재료 리스트:['돌나물', '사과'] 108번째 레시피
# 재료의 개수:1 재료 리스트:['냉동새우'] 109번째 레시피
# 재료의 개수:4 재료 리스트:['파프리카 빨강이', '파프리카 노랑이', '느타리버섯', '대파'] 110번째 레시피
# 재료의 개수:3 재료 리스트:['또띠아', '버터', '피자치즈'] 111번째 레시피
# 재료의 개수:4 재료 리스트:['신김치', '계란', '통조림햄', '양파'] 112번째 레시피
# 재료의 개수:5 재료 리스트:['메추리알', '곤약', '당근', '건표고', '대파'] 113번째 레시피
# 재료의 개수:2 재료 리스트:['감자', '감자 전분'] 114번째 레시피
# 재료의 개수:3 재료 리스트:['사각어묵', '땡초', '통마늘'] 115번째 레시피
# 재료의 개수:6 재료 리스트:['양배추', '닭가슴살', '깻잎', '빨간 파프리카', '당근', '새송이버섯'] 116번째 레시피
# 재료의 개수:3 재료 리스트:['감자', '전분', '우유'] 117번째 레시피
# 재료의 개수:3 재료 리스트:['두부', '카레가루', '계란'] 118번째 레시피
# 재료의 개수:3 재료 리스트:['감자', '비엔나소시지', '청양고추'] 119번째 레시피
# 재료의 개수:1 재료 리스트:['데쳐서 물기짠 봄동'] 120번째 레시피
# 재료의 개수:1 재료 리스트:['비엔나소세지'] 121번째 레시피
# 재료의 개수:2 재료 리스트:['양배추채', '베이컨'] 122번째 레시피
# 재료의 개수:2 재료 리스트:['계란', '대파'] 123번째 레시피
# 재료의 개수:3 재료 리스트:['가지', '마늘', '설탕 적은'] 124번째 레시피
# 재료의 개수:4 재료 리스트:['가지', '양파', '노란 파프리카', '빨간 파프리카'] 125번째 레시피
# 재료의 개수:3 재료 리스트:['황태채', '전분', '튀김기름'] 126번째 레시피
# 재료의 개수:2 재료 리스트:['항정살', '양상추 샐러드채소'] 127번째 레시피
# 재료의 개수:4 재료 리스트:['팽이버섯', '양파', '대파', '계란'] 128번째 레시피
# 재료의 개수:3 재료 리스트:['닭가슴살', '양파', '버터'] 129번째 레시피
# 재료의 개수:1 재료 리스트:['식빵'] 130번째 레시피
# 재료의 개수:3 재료 리스트:['가지', '소고기등심', '새싹채소'] 131번째 레시피
# 재료의 개수:2 재료 리스트:['닭가슴살', '대파'] 132번째 레시피
# 재료의 개수:4 재료 리스트:['새우살', '당근', '매운고추', '전분'] 133번째 레시피
# 재료의 개수:1 재료 리스트:['청경채'] 134번째 레시피
# 재료의 개수:1 재료 리스트:['치킨 너겟'] 135번째 레시피
# 재료의 개수:2 재료 리스트:['통마늘', '아몬드'] 136번째 레시피
# 재료의 개수:4 재료 리스트:['차돌박이', '부추', '양파', '홍고추'] 137번째 레시피
# 재료의 개수:5 재료 리스트:['떡볶이떡', '양파', '파프리카', '체다치즈', '모짜렐라치즈'] 138번째 레시피
# 재료의 개수:4 재료 리스트:['달걀', '당근', '양파', '쪽파'] 139번째 레시피
# 재료의 개수:1 재료 리스트:['마늘'] 140번째 레시피
# 재료의 개수:3 재료 리스트:['돼지고기삼겹살 또는 목살', '겨자', '다진대파'] 141번째 레시피
# 재료의 개수:6 재료 리스트:['달걀', '슬라이스햄', '슬라이스치즈', '샐러드채소', '방울토마토', '스리라차소스'] 142번째 레시피
# 재료의 개수:2 재료 리스트:['통마늘', '새우'] 143번째 레시피
# 재료의 개수:1 재료 리스트:['속배추'] 144번째 레시피
# 재료의 개수:6 재료 리스트:['양배추', '참치', '양파', '애호박', '버섯', '쪽파'] 145번째 레시피
# 재료의 개수:2 재료 리스트:['닭가슴살', '새송이버섯'] 146번째 레시피
# 재료의 개수:6 재료 리스트:['순두부', '다진돼지고기', '양파', '대파', '당근', '홍고추'] 147번째 레시피
# 재료의 개수:3 재료 리스트:['식빵', '우유', '버터'] 148번째 레시피
# 재료의 개수:3 재료 리스트:['참치캔 기본사이즈', '양파', '당근'] 149번째 레시피
# 재료의 개수:2 재료 리스트:['시금치', '두부'] 150번째 레시피
# 재료의 개수:6 재료 리스트:['숙주', '달걀', '새우', '양파', '청양고추', '쪽파'] 151번째 레시피
# 재료의 개수:3 재료 리스트:['식빵', '캔옥수수', '피자치즈'] 152번째 레시피
# 재료의 개수:2 재료 리스트:['닭봉', '우유'] 153번째 레시피
# 재료의 개수:3 재료 리스트:['애호박', '양파', '고추기름'] 154번째 레시피
# 재료의 개수:6 재료 리스트:['감자', '참치캔', '양파', '대파', '청양고추', '다시육수'] 155번째 레시피
# 재료의 개수:1 재료 리스트:['돼지고기 목살'] 156번째 레시피
# 재료의 개수:3 재료 리스트:['돼지 앞다리살', '청경채', '파프리카'] 157번째 레시피
# 재료의 개수:1 재료 리스트:['손질 오징어'] 158번째 레시피
# 재료의 개수:1 재료 리스트:['미니 돈까스'] 159번째 레시피
# 재료의 개수:2 재료 리스트:['팽이버섯', '청양고추'] 160번째 레시피
# 재료의 개수:4 재료 리스트:['모닝빵', '햄', '피자치즈 큰', '옥수수콘 큰'] 161번째 레시피
# 재료의 개수:1 재료 리스트:['마늘'] 162번째 레시피
# 재료의 개수:7 재료 리스트:['새송이버섯', '양송이버섯', '빨강파프리카', '노랑파프리카', '양파', '가지', '애호박'] 163번째 레시피
# 재료의 개수:1 재료 리스트:['상추'] 164번째 레시피
# 재료의 개수:3 재료 리스트:['두부', '대파', '청양고추'] 165번째 레시피
# 재료의 개수:4 재료 리스트:['양파', '스팸', '계란', '파'] 166번째 레시피
# 재료의 개수:2 재료 리스트:['손질된 고등어', '녹말가루'] 167번째 레시피
# 재료의 개수:2 재료 리스트:['두부 약200g', '대파'] 168번째 레시피
# 재료의 개수:2 재료 리스트:['또띠아', '버터'] 169번째 레시피
# 재료의 개수:1 재료 리스트:['가래떡 영상에선 한뼘 두개 사용'] 170번째 레시피
# 재료의 개수:2 재료 리스트:['부추', '베이컨'] 171번째 레시피
# 재료의 개수:2 재료 리스트:['닭고기', '대파'] 172번째 레시피
# 재료의 개수:4 재료 리스트:['참치', '감자 작은거', '양파', '대파'] 173번째 레시피
# 재료의 개수:3 재료 리스트:['후랑크 소시지', '피자치즈', '양파'] 174번째 레시피
# 재료의 개수:2 재료 리스트:['식빵', '캔옥수수'] 175번째 레시피
# 재료의 개수:4 재료 리스트:['미니새송이버섯', '통마늘', '양파', '청양고추'] 176번째 레시피
# 재료의 개수:4 재료 리스트:['닭다리살', '고구마', '브로콜리', '미니파프리카'] 177번째 레시피
# 재료의 개수:2 재료 리스트:['양파', '영양부추'] 178번째 레시피
# 재료의 개수:2 재료 리스트:['감자', '양파'] 179번째 레시피
# 재료의 개수:2 재료 리스트:['양파', '대파'] 180번째 레시피
# 재료의 개수:2 재료 리스트:['두부', '다진소고기'] 181번째 레시피
# 재료의 개수:3 재료 리스트:['전분', '계란', '크래미맛살'] 182번째 레시피
# 재료의 개수:2 재료 리스트:['표고버섯', '달걀'] 183번째 레시피
# 재료의 개수:1 재료 리스트:['냉동만두'] 184번째 레시피
# 재료의 개수:2 재료 리스트:['알새우', '양파'] 185번째 레시피
# 재료의 개수:2 재료 리스트:['두툼한 돼지고기', '튀김가루'] 186번째 레시피
# 재료의 개수:2 재료 리스트:['돼지고기앞다리살', '마늘'] 187번째 레시피
# 재료의 개수:3 재료 리스트:['닭다리살 정육', '바질가루', '버터'] 188번째 레시피
# 재료의 개수:2 재료 리스트:['오징어', '꽈리고추'] 189번째 레시피
# 재료의 개수:3 재료 리스트:['통조림햄 참치.돼지고기.등도 가능', '부추', '청양고추'] 190번째 레시피
# 재료의 개수:2 재료 리스트:['브로콜리', '마늘'] 191번째 레시피
# 재료의 개수:5 재료 리스트:['밀가루박력분', '무염버터', '우유', '베이킹파우더', '딸기잼'] 192번째 레시피
# 재료의 개수:7 재료 리스트:['다시마멸치육수', '만두', '달걀', '느타리버섯', '양파', '대파', '청양고추'] 193번째 레시피
# 재료의 개수:4 재료 리스트:['닭다리살', '피자치즈', '양파', '파'] 194번째 레시피
# 재료의 개수:1 재료 리스트:['무 보통사이즈'] 195번째 레시피
# 재료의 개수:3 재료 리스트:['미역 1인분', '오이', '양파 작은것'] 196번째 레시피
# 재료의 개수:2 재료 리스트:['두부 부침용', '각종채소'] 197번째 레시피
# 재료의 개수:3 재료 리스트:['닭가슴살', '카레가루', '밀가루 or 전분가루'] 198번째 레시피
# 재료의 개수:2 재료 리스트:['두부', '계란'] 199번째 레시피
# 재료의 개수:5 재료 리스트:['삽겹살', '홍고추', '청양고추', '양파', '쪽파'] 200번째 레시피
# 재료의 개수:5 재료 리스트:['양송이버섯', '닭가슴살', '양파', '파프리카', '치즈'] 201번째 레시피
# 재료의 개수:1 재료 리스트:['우유'] 202번째 레시피
# 재료의 개수:3 재료 리스트:['닭가슴살', '고구마 작은 것', '대파'] 203번째 레시피
# 재료의 개수:3 재료 리스트:['오이', '참치 1캔 100g', '양파'] 204번째 레시피
# 재료의 개수:1 재료 리스트:['달걀'] 205번째 레시피
# 재료의 개수:2 재료 리스트:['맛살', '대파'] 206번째 레시피
# 재료의 개수:5 재료 리스트:['델큐브 참치', '양파', '당근', '대파', '계란'] 207번째 레시피
# 재료의 개수:5 재료 리스트:['차돌박이', '양파', '청량고추', '홍고추', '통마늘'] 208번째 레시피
# 재료의 개수:6 재료 리스트:['계란', '버터', '양파', '피망', '햄', '피자치즈'] 209번째 레시피
# 재료의 개수:6 재료 리스트:['양파', '당근', '호박', '청양고추', '햄', '계란'] 210번째 레시피
# 재료의 개수:6 재료 리스트:['계란', '파프리카 빨강', '파프리카 노랑', '애호박 다진 것', '다진당근', '대파 다진 것'] 211번째 레시피
# 재료의 개수:1 재료 리스트:['팽이버섯'] 212번째 레시피
# 재료의 개수:6 재료 리스트:['닭가슴살', '부추', '파프리카', '오이', '양파', '당근'] 213번째 레시피
# 재료의 개수:4 재료 리스트:['숙주', '계란', '대파', '칵테일새우'] 214번째 레시피
# 재료의 개수:5 재료 리스트:['닭가슴살통조림', '양배추', '당근', '오이', '칠리소스'] 215번째 레시피
# 재료의 개수:2 재료 리스트:['감자', '고추 또는 쪽파'] 216번째 레시피
# 재료의 개수:3 재료 리스트:['만두', '대파', '쥐똥고추 or청양고추'] 217번째 레시피
# 재료의 개수:4 재료 리스트:['두부', '계란', '우유', '부추'] 218번째 레시피
# 재료의 개수:4 재료 리스트:['두부 300g', '설탕 취향에 따라 가감', '생강파우더 or 생강 다진 것 1/2t', '대파 흰대 다진 것'] 219번째 레시피
# 재료의 개수:1 재료 리스트:['두부'] 220번째 레시피
# 재료의 개수:2 재료 리스트:['칵테일새우 중간크기', '버터'] 221번째 레시피
# 재료의 개수:3 재료 리스트:['고구마', '버터', '피자치즈'] 222번째 레시피
# 재료의 개수:3 재료 리스트:['호두', '달걀 흰자', '밀가루'] 223번째 레시피
# 재료의 개수:4 재료 리스트:['냉동 새우살', '양파', '애호박', '대파'] 224번째 레시피
# 재료의 개수:4 재료 리스트:['맛살', '깻잎', '달걀', '밀가루'] 225번째 레시피
# 재료의 개수:5 재료 리스트:['파스타면', '청양고추', '마늘', '버터', '새우'] 226번째 레시피
# 재료의 개수:1 재료 리스트:['두부'] 227번째 레시피
# 재료의 개수:1 재료 리스트:['돼지목살'] 228번째 레시피
# 재료의 개수:5 재료 리스트:['식빵', '양파', '샌드위치햄', '캔옥수수', '모짜렐라 치즈'] 229번째 레시피
# 재료의 개수:3 재료 리스트:['닭가슴살', '양배추', '대파'] 230번째 레시피
# 재료의 개수:3 재료 리스트:['닭가슴살', '양파', '깻잎'] 231번째 레시피
# 재료의 개수:3 재료 리스트:['계란', '참치', '대파'] 232번째 레시피
# 재료의 개수:3 재료 리스트:['대패삼겹살', '양파', '달걀 노른자'] 233번째 레시피
# 재료의 개수:4 재료 리스트:['식빵', '슬라이스치즈', '슬라이스햄', '달걀'] 234번째 레시피
# 재료의 개수:4 재료 리스트:['감자 큰크기', '슬라이스치즈', '우유', '구운베이컨 잘게 썬'] 235번째 레시피
# 재료의 개수:2 재료 리스트:['연두부', '어린 새싹'] 236번째 레시피
# 재료의 개수:4 재료 리스트:['연두부', '어린잎채소', '파프리카', '양파'] 237번째 레시피
# 재료의 개수:1 재료 리스트:['치킨너겟'] 238번째 레시피
# 재료의 개수:3 재료 리스트:['계란', '연두부', '치즈'] 239번째 레시피
# 재료의 개수:3 재료 리스트:['애호박', '양파', '달걀'] 240번째 레시피
# 재료의 개수:3 재료 리스트:['청포묵', '대파 잎', '김가루'] 241번째 레시피
# 재료의 개수:7 재료 리스트:['새우', '양파', '당근', '마늘', '청양고추', '버터', '카레가루'] 242번째 레시피
# 재료의 개수:5 재료 리스트:['오징어', '무', '애호박', '청양고추', '액젓'] 243번째 레시피
# 재료의 개수:4 재료 리스트:['박력분', '베이킹파우더', '버터', '우유'] 244번째 레시피
# 재료의 개수:1 재료 리스트:['참치 캔'] 245번째 레시피
# 재료의 개수:4 재료 리스트:['닭가슴살', '당근', '브로콜리 자른것', '계란'] 246번째 레시피
# 재료의 개수:2 재료 리스트:['양송이 버섯', '잔파'] 247번째 레시피
# 재료의 개수:3 재료 리스트:['계란', '오이', '당근'] 248번째 레시피
# 재료의 개수:4 재료 리스트:['식빵', '베이컨', '계란', '슬라이스치즈'] 249번째 레시피
# 재료의 개수:1 재료 리스트:['만두'] 250번째 레시피
# 재료의 개수:5 재료 리스트:['부침용 두부', '양파', '당근', '아몬드슬라이스', '호두'] 251번째 레시피
# 재료의 개수:5 재료 리스트:['채 썬 표고버섯', '채 썬 양파', '채 썬 당근', '소고기', '전분'] 252번째 레시피
# 재료의 개수:2 재료 리스트:['새송이버섯', '버터'] 253번째 레시피
# 재료의 개수:3 재료 리스트:['옥수수콘', '모닝빵', '모짜렐라치즈'] 254번째 레시피
# 재료의 개수:2 재료 리스트:['양배추', '두부'] 255번째 레시피
# 재료의 개수:3 재료 리스트:['햇반', '베이컨', '슬라이스 치즈'] 256번째 레시피
# 재료의 개수:2 재료 리스트:['박력분', '으깬감자'] 257번째 레시피
# 재료의 개수:3 재료 리스트:['닭가슴살 통조림 중간크기', '양파 작은거', '양배추'] 258번째 레시피
# 재료의 개수:4 재료 리스트:['만두', '마늘', '대파', '버터'] 259번째 레시피
# 재료의 개수:4 재료 리스트:['당면', '계란', '당근', '깻잎'] 260번째 레시피
# 재료의 개수:2 재료 리스트:['감자큰거', '버터'] 261번째 레시피
# 재료의 개수:4 재료 리스트:['스팸', '계란', '깻잎', '밀가루'] 262번째 레시피
# 재료의 개수:3 재료 리스트:['식빵', '체다치즈', '모짜렐라 치즈'] 263번째 레시피
# 재료의 개수:3 재료 리스트:['두부', '양파', '대파'] 264번째 레시피
# 재료의 개수:5 재료 리스트:['두부', '크래미', '달걀', '당근', '깻잎'] 265번째 레시피
# 재료의 개수:3 재료 리스트:['시금치 원하는 만큼', '통마늘', '베이컨'] 266번째 레시피
# 재료의 개수:3 재료 리스트:['닭다리살', '양파', '계란'] 267번째 레시피
# 재료의 개수:3 재료 리스트:['달래', '홍고추', '구운김'] 268번째 레시피
# 재료의 개수:5 재료 리스트:['느타리버섯', '청고추', '홍고추', '마늘', '튀김기름'] 269번째 레시피
# 재료의 개수:3 재료 리스트:['메추리알', '비엔나소세지', '청양고추'] 270번째 레시피
# 재료의 개수:3 재료 리스트:['느타리버섯', '표고버섯', '쪽파'] 271번째 레시피
# 재료의 개수:3 재료 리스트:['통삼겹살', '붉은 양파', '파채'] 272번째 레시피
# 재료의 개수:4 재료 리스트:['당면', '표고버섯', '청량고추', '대파'] 273번째 레시피
# 재료의 개수:5 재료 리스트:['닭안심', '감자 작은 것', '대파', '우유', '당면'] 274번째 레시피
# 재료의 개수:5 재료 리스트:['건미역', '오이', '맛살', '무', '연겨자'] 275번째 레시피
# 재료의 개수:4 재료 리스트:['삼겹살', '양파', '양배추', '계란'] 276번째 레시피
# 재료의 개수:1 재료 리스트:['가지 약 24cm'] 277번째 레시피
# 예상치 못한 오류 발생: 'NoneType' object has no attribute 'select_one'

# %%
# c_df = pd.read_csv('만개의레시피(최종결과)_f.csv')

# %%
c_df = result

# %%
# 'viewNumber' 컬럼의 값들을 순회하며 처리합니다.
for idx, view_num in c_df['viewNumber'].items():
    # '조회수'를 제거합니다.
    view_num_str = str(view_num)
    view_num_cleaned = view_num_str.replace('조회수', '')
    # 쉼표를 제거합니다.
    view_num_cleaned = view_num_cleaned.replace(',', '')
    # '만'이 포함된 경우에만 처리합니다.
    if '만' in view_num_cleaned:
        # '만'을 제외한 숫자 값만 추출합니다.
        num_only = float(view_num_cleaned.replace('만', '')) * 10000
    else:
        # '만'이 없는 경우에는 그냥 숫자로 변환합니다.
        num_only = float(view_num_cleaned)
    # 처리한 값을 'viewNumber' 컬럼에 업데이트합니다.
    c_df.at[idx, 'viewNumber'] = num_only

# %%
# 'view_Number' 열의 데이터 타입을 int로 변경합니다.
c_df['viewNumber'] = c_df['viewNumber'].astype(int)

# 'view_Number' 열에서 5000 이하의 값을 가진 행을 필터링합니다.
less_than_or_equal_to_5000 = c_df[c_df['viewNumber'] <= 5000]

# 5000 이하의 값을 가진 행이 있는지 확인합니다.
if not less_than_or_equal_to_5000.empty:
    print("5000 이하의 값이 존재합니다.")
    print(less_than_or_equal_to_5000)
else:
    print("5000 이하의 값이 존재하지 않습니다.")
# Out:
# 5000 이하의 값이 존재하지 않습니다.

# %%
c_df.to_csv('C:\\Users\\gudrb\\OneDrive\\Desktop\\캡디\\만개의레시피(최종결과)_c.csv', index=False, encoding='utf-8-sig')
